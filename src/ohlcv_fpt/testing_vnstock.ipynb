# %%
! pip install vnstock
# Out:
# ...
#   Using cached vnstock-4.0.4-py3-none-any.whl.metadata (59 kB)
# ...
#   Using cached vnai-2.4.8-py3-none-any.whl.metadata (691 bytes)
# ...
#   Using cached vnstock_ezchart-1.0.2-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# ...
# Using cached vnstock-4.0.4-py3-none-any.whl (279 kB)
# Using cached vnai-2.4.8-py3-none-any.whl (48 kB)
# Using cached vnstock_ezchart-1.0.2-py3-none-any.whl (22 kB)
# Using cached mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [vnstock]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip

# %%
from vnstock import Reference, show_api, show_doc

# Khởi tạo đối tượng Reference
ref = Reference()

# %%
from vnstock import Fundamental

# Khởi tạo đối tượng Fundamental
fun = Fundamental()

# %%
fun.equity(symbol='FPT').income_statement()
# Out:
# <div style='background-color: #e3f2fd; border-left: 4px solid #2196f3; padding: 12px 16px; margin: 12px 0; border-radius: 4px; font-size: 13px;'><strong>ℹ️  Phiên bản cộng đồng</strong><br>Báo cáo tài chính được giới hạn tối đa <strong>4 kỳ</strong> để minh hoạ thuật toán. Để truy cập đầy đủ tất cả các kỳ báo cáo, vui lòng <a href='https://vnstocks.com/insiders-program' target='_blank'>tham gia gói thành viên tài trợ dự án</a>.</div>
#                                                  item  \
# 0          1. Doanh thu bán hàng và cung cấp dịch vụ
# 1                     2. Các khoản giảm trừ doanh thu
# 2   3. Doanh thu thuần về bán hàng và cung cấp dịc...
# 3                                4. Giá vốn hàng bán
# 4    5. Lợi nhuận gộp về bán hàng và cung cấp dịch vụ
# 5   6. Lãi/Lỗ của hoạt động bán, thanh lý bất động...
# 6                   7. Doanh thu hoạt động tài chính
# 7                               8. Chi phí tài chính
# 8                            Trong đó: Chi phí đi vay
# ...
