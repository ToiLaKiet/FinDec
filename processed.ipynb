# %%
import json
with open('data/processed/cafef_2023_first1000.jsonl', 'r') as f:
    first1000 = [json.loads(line) for line in f]

# %%
first1000[0]
# Out:
# {'article_id': '188231229103257892',
#  'title': 'Thủy điện Hủa Na (HNA) ước lãi 217 tỷ đồng, lên sàn HoSE ngay trong tháng 1/2024',
#  'published_date': '2023-12-29',
#  'url': 'https://cafef.vn/thuy-dien-hua-na-hna-uoc-lai-217-ty-dong-len-san-hose-ngay-trong-thang-1-2024-188231229103257892.chn',
#  'label': {'doc_id': '188231229103257892',
#   'language': 'vi',
#   'main_topic': 'earnings',
#   'entities': [{'name': 'Công ty Cổ phần Thủy điện Hủa Na',
#     'type': 'Company',
#     'ticker': 'HNA',
#     'role_in_article': 'subject'},
#    {'name': 'Công ty Cổ phần Chứng khoán Rồng Việt',
#     'type': 'Company',
#     'ticker': None,
#     'role_in_article': 'mentioned'},
#    {'name': 'Sở Giao dịch Chứng khoán Thành phố Hồ Chí Minh',
#     'type': 'Organization',
#     'ticker': None,
#     'role_in_article': 'mentioned'}],
#   'events': [{'event_type': 'earnings_report',
#     'entities_involved': ['Công ty Cổ phần Thủy điện Hủa Na'],
# ...
